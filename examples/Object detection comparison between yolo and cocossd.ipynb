# %% [markdown]
# # YOLO vs. CocoSsd
#
# In this notebook, we will perform a comparison between yolo and cocossd.

# %%
from ml5_ipynb import ml5_detector
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img_path = 'pic/people_ani3.jpg'
img = cv2.imread(img_path)
img_rgba = cv2.cvtColor(img, cv2.COLOR_BGR2RGBA)
width = 640
height = 420
resize_size = (width, height)
img_rgba = cv2.resize(img_rgba, resize_size)
x, y, channel = img_rgba.shape
print(x,y,channel)
plt.imshow(img_rgba)
# Out:
# 420 640 4

# %% [markdown]
# ### YOLO

# %%
yolo = ml5_detector.ObjectDetector('yolo')
# Out:
# VBox(children=(ObjectDetector(status='deferring flush until render'), Text(value='deferring flush until render…
# ........Model is ready

# %%
yolo.image_detect(img_rgba,width=width,height=height)
# Out:
# .........done
# CPU times: user 2.71 s, sys: 103 ms, total: 2.81 s
# Wall time: 3.89 s

# %%
yolo.draw_bounding_box(img_rgba)
# Out:
# person 44 0 163 387

# %% [markdown]
# ### CocoSsd

# %%
coco = ml5_detector.ObjectDetector('cocossd')
# Out:
# VBox(children=(ObjectDetector(status='deferring flush until render'), Text(value='deferring flush until render…
# .........Model is ready

# %%
coco.image_detect(img_rgba,width=width,height=height)
# Out:
# ........done
# CPU times: user 2.71 s, sys: 99.3 ms, total: 2.8 s
# Wall time: 3.77 s

# %%
coco.draw_bounding_box(img_rgba)
# Out:
# person 34 0 197 412
# cow 303 74 326 234
