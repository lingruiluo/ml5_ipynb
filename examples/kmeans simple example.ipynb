# %% [markdown]
# # Image Clutering with Kmeans
#
# Kmeans is a cluter method. It can also used for image clustering or segmentation, even thought the performance is not as good as more complex algorithms. In this notebook, I will show how to use kmeans in ml5_ipynb to cluter on an image.

# %%
from ml5_ipynb import ml5_kmeans

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
test = ml5_kmeans.Kmeans() # create kmeans object

# %% [markdown]
# We will first resize the image to $50\times 50$ in order to speed up the process. The rgb values of the image are the input data, you can also see it as a color clutering.

# %%
img = cv2.imread('pic/faces.jpg')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
resize_size = (50, 50)
img_rgb = cv2.resize(img_rgb, resize_size)

# %%
plt.imshow(img_rgb)

# %%
x, y, channel = img_rgb.shape
x, y, channel
# Out:
# (50, 50, 3)

# %%
for i in range(x):
    for j in range(y):
        r, g, b = img_rgb[i,j]
        test.data.append({'r':r, 'g':g, 'b':b})

# %% [markdown]
# The default number of cluster is 3 in setting, here we set it to 5.

# %%
test.options['k']=2

# %%
test.initialize() # initialize kmeans framework
# Out:
# done

# %%
colorDict = {0: [88, 214, 141],
             1: [202, 207, 210],
             2: [97, 106, 107],
             3: [44, 62, 80],
             4: [249, 231, 159]}

# %%
output_img = []
for c in test.data_label:
    output_img.append(c)
output_img = np.array(output_img).reshape(resize_size)

# %%
plt.imshow(output_img)

# %% [markdown]
# We can see from the resulted image that kmeans can cluster human from background.

# %% [markdown]
# ____________

# %%
# alternative way to read image
# from PIL import Image

# im = Image.open('world.jpg')
# im = im.resize((30, 30))
# pixel_values = list(im.getdata())

# %%
# for i in range(len(pixel_values)):
#     r, g, b = pixel_values[i]
#     test.add_data({'r':r, 'g':g, 'b':b})

# %% [markdown]
# __________
